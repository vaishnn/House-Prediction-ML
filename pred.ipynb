# %% [markdown]
# Importing libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Loading DataSet

# %%
data_house = pd.read_csv("dataset/train (1).csv");
data_house.head()
#Checking Data is Loaded perfectly
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# Checking the info of Data Set

# %%
data = data_house.copy()
data.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# Removing Column with Missing Value(More than 50%)

# %%
data.isnull().sum().sort_values(ascending=False).iloc[:20,]
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageCond        81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# Id                 0
# dtype: int64

# %%
data.drop(columns=["PoolQC","MiscFeature","Alley","Fence","FireplaceQu","LotFrontage"], inplace=True)

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    Inside       Gtl  ...             0         0           0        0
# 1       FR2       Gtl  ...             0         0           0        0
# 2    Inside       Gtl  ...             0         0           0        0
# 3    Corner       Gtl  ...           272         0           0        0
# 4       FR2       Gtl  ...             0         0           0        0
#
#   MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# ...

# %%
object_col = data.columns

# %% [markdown]
# Dropping Some More Variable for Reducing OverFitting

# %%
data = data.drop(columns=["Street","MSZoning","LotShape","LandContour","RoofMatl","ExterCond","BsmtFinType2","Heating","Functional"])

# %%
data = data.drop(columns=["Utilities","SaleType","LandSlope"])

# %%
data.head()
# Out:
#    Id  MSSubClass  LotArea LotConfig Neighborhood Condition1 Condition2  \
# 0   1          60     8450    Inside      CollgCr       Norm       Norm
# 1   2          20     9600       FR2      Veenker      Feedr       Norm
# 2   3          60    11250    Inside      CollgCr       Norm       Norm
# 3   4          70     9550    Corner      Crawfor       Norm       Norm
# 4   5          60    14260       FR2      NoRidge       Norm       Norm
#
#   BldgType HouseStyle  OverallQual  ...  OpenPorchSF  EnclosedPorch  \
# 0     1Fam     2Story            7  ...           61              0
# 1     1Fam     1Story            6  ...            0              0
# 2     1Fam     2Story            7  ...           42              0
# 3     1Fam     2Story            7  ...           35            272
# 4     1Fam     2Story            8  ...           84              0
#
#    3SsnPorch ScreenPorch PoolArea MiscVal MoSold  YrSold SaleCondition  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 63 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   LotArea        1460 non-null   int64
#  3   LotConfig      1460 non-null   object
#  4   Neighborhood   1460 non-null   object
#  5   Condition1     1460 non-null   object
#  6   Condition2     1460 non-null   object
#  7   BldgType       1460 non-null   object
#  8   HouseStyle     1460 non-null   object
#  9   OverallQual    1460 non-null   int64
#  10  OverallCond    1460 non-null   int64
#  11  YearBuilt      1460 non-null   int64
#  12  YearRemodAdd   1460 non-null   int64
#  13  RoofStyle      1460 non-null   object
#  14  Exterior1st    1460 non-null   object
#  15  Exterior2nd    1460 non-null   object
#  16  MasVnrType     1452 non-null   object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
for col in object_col:
    encoder = LabelEncoder()
    data[col] = encoder.fit_transform(data[col])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 63 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   LotArea        1460 non-null   int64
#  3   LotConfig      1460 non-null   int32
#  4   Neighborhood   1460 non-null   int32
#  5   Condition1     1460 non-null   int32
#  6   Condition2     1460 non-null   int32
#  7   BldgType       1460 non-null   int32
#  8   HouseStyle     1460 non-null   int32
#  9   OverallQual    1460 non-null   int64
#  10  OverallCond    1460 non-null   int64
#  11  YearBuilt      1460 non-null   int64
#  12  YearRemodAdd   1460 non-null   int64
#  13  RoofStyle      1460 non-null   int32
#  14  Exterior1st    1460 non-null   int32
#  15  Exterior2nd    1460 non-null   int32
#  16  MasVnrType     1460 non-null   int32
#  17  MasVnrArea     1460 non-null   int64
# ...

# %% [markdown]
# Feature Selection

# %%
data.head()
# Out:
#    Id  MSSubClass  LotArea  LotConfig  Neighborhood  Condition1  Condition2  \
# 0   0           5      327          4             5           2           2
# 1   1           0      498          2            24           1           2
# 2   2           5      702          4             5           2           2
# 3   3           6      489          0             6           2           2
# 4   4           5      925          2            15           2           2
#
#    BldgType  HouseStyle  OverallQual  ...  OpenPorchSF  EnclosedPorch  \
# 0         0           5            6  ...           49              0
# 1         0           2            5  ...            0              0
# 2         0           5            6  ...           30              0
# 3         0           5            6  ...           24            108
# 4         0           5            7  ...           70              0
#
#    3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleCondition  \
# ...

# %% [markdown]
# Treating Missing Values "NA"

# %%
plt.figure(figsize=(16,5))
sns.lineplot(x=data["LotArea"],y=data["SalePrice"]);
plt.title("Lot Area VS Sale Price")

plt.figure(figsize=(16,5))
sns.lineplot(x = data["YearBuilt"], y = data["SalePrice"])
plt.title("Year Build VS Sale Price")

plt.figure(figsize=(16,5))
sns.lineplot(x = data["OverallQual"], y = data["SalePrice"])
plt.title("Overall Quality VS Sale Price")

plt.figure(figsize=(16,5))
sns.lineplot(x = data["OverallCond"], y = data["SalePrice"])
plt.title("Overall Condition VS Sale Price")

plt.figure(figsize=(16,5))
sns.lineplot(x = data["MSSubClass"], y = data["SalePrice"])
plt.title("MSSubClass VS Sale Price")

plt.figure(figsize=(16,5))
sns.lineplot(x = data["GrLivArea"], y = data["SalePrice"])
plt.title("GrLivArea VS Sale Price")
# Out:
# Text(0.5, 1.0, 'GrLivArea VS Sale Price')

# %% [markdown]
# Choosing the Feature for training the algorithms

# %% [markdown]
# So Choosing "OverAllQual" , "GrLivArea" , "OverAllCond" , "YearBuild" for training the Algorithm

# %%
x = data[["OverallQual","GrLivArea","OverallCond","YearBuilt"]]
y = data[["SalePrice"]]

# %% [markdown]
# Treating Missing DataSet

# %%
x.head()
# Out:
#    OverallQual  GrLivArea  OverallCond  YearBuilt
# 0            6        531            4        104
# 1            5        259            7         77
# 2            6        570            4        102
# 3            6        536            4         19
# 4            7        734            4        101

# %% [markdown]
# Test and Train Split of Data

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.5);

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression

regress_model = LinearRegression()
regress_model.fit(xtrain,ytrain);

# %%
y_pred = regress_model.predict(xtest)

# %%
for i in range(y_pred.shape[0]):
    if(y_pred[i] < 0):
        y_pred[i] = 0

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_squared_log_error
mean_squared_log_error(ytest,y_pred)
# Out:
# 0.3828023117032488

# %%
r2_score(ytest,y_pred)
# Out:
# 0.8284836106255371

# %%
print(x.max())
print(x.min())
# Out:
# OverallQual      9
# GrLivArea      860
# OverallCond      8
# YearBuilt      111
# dtype: int64
# OverallQual    0
# GrLivArea      0
# OverallCond    0
# YearBuilt      0
# dtype: int64
